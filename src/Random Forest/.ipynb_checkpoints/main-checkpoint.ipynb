# %%
df = pd.read_csv("./Position_Salaries.csv")
df.describe()
# Out:
#         Level        Salary
# count  48.000  4.800000e+01
# mean   12.250  1.425490e+07
# std     7.000  2.627770e+07
# min     0.500  3.000000e+04
# 25%     6.375  1.687500e+05
# 50%    12.250  2.400000e+06
# 75%    18.125  1.450000e+07
# max    24.000  1.200000e+08

# %%
X = df.loc[:, ["Level"]]
y = df["Salary"]

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state=1997, n_estimators=100)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
y_pred
# Out:
# array([ 5160000.,    50650.,  3208000.,  7070000.,  8970000., 17050000.,
#        11460000., 27500000.,    76150.,   119050.])

# %%
import matplotlib.pyplot as plt

plt.plot(X, y, color="green")
plt.xlabel("Level")
plt.ylabel("Salary")
plt.scatter(X_test, y_pred)
plt.grid(True, alpha=0.3)

# %%
residuals = y_test - y_pred

# %%
plt.scatter(y_test, residuals)
plt.axhline(0, color="red", linestyle="--")
plt.xlabel("Valores reales (y_test)")
plt.ylabel("Errores (Residuales)")
plt.title("Gráfico de Residuales")
plt.show()
