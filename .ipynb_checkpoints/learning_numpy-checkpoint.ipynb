# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr.mean()
# Out:
# np.float64(3.0)

# %%
arr.min()
# Out:
# np.int64(1)

# %%
arr = np.random.randint(1, 101, 50)
arr
# Out:
# array([ 88,  27,  89,  68,  97,   1,  31,  52,  85, 100,  10,  38,  52,
#         29,  71,  92,  68,  47,  56,  90,  48,  80,  58,  82,  82,  65,
#          2,  49,  33,  46,  71,  38,   7,  78,  82,  24,  21,  26,  18,
#         92,  82,  31,  92,  54,  96,  77,  55,  84,  91,  39])

# %% [markdown]
# # Numpy

# %%
arr = np.array([1,2,3,4,5])
arr
arr.mean()
arr.min()
arr = np.random.randint(1, 101, 50)
arr
# Out:
# array([ 52,  14,  51,  59,   7,  98,  72,  47,  83,  68,  67,  16,  27,
#         31,  12,  64,  22,   2,  25,  82,  76,  72,  10,  54,  21, 100,
#         80,   2,  80,  82,  98,  75,  75,  12,  42, 100,   4,  21,  91,
#         53,  79,  63,  84,  54,  17,  81,  68,  74,  33,  47])
