# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr.mean()
# Out:
# np.float64(3.0)

# %%
arr.min()
# Out:
# np.int64(1)

# %%
arr = np.random.randint(1, 101, 50)
arr
# Out:
# array([14, 86, 82, 50, 17, 57, 60, 79, 96, 68, 27, 27, 80, 90, 57, 28, 26,
#        91, 75, 77, 38, 75, 73, 11, 37, 41, 68, 63, 69, 80, 80, 91, 94, 71,
#        58, 31, 86, 22, 41, 52, 13,  2, 67, 67, 62, 18, 23, 75, 64, 72])

# %% [markdown]
# # Numpy
